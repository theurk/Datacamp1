# %% [markdown]
# # แบบที่ 1

# %%
import pandas as pd

# %%
url = 'https://www.settrade.com/C13_MarketSummary.jsp?detail=SET50'

# %%
df = pd.read_html(url)

# %%
len(df)
# Out:
# 6

# %%
df
# Out:
# [  Unnamed: 0   ล่าสุด  เปลี่ยน  แปลง  %เปลี่ยน  แปลง   สูงสุด   ต่ำสุด  \
#  0        SET  1482.38          -1.51           -0.10  1489.78  1475.01
#  1      SET50   947.28          -1.71           -0.18   953.60   940.86
#  2     SET100  2116.85          -3.39           -0.16  2130.57  2103.80
#  3       sSET   721.04          -1.61           -0.22   726.51   720.68
#  4    SETCLMV   970.42          -6.03           -0.62   979.68   965.81
#  5      SETHD  1050.40          -4.11           -0.39  1058.45  1042.83
#  6    SETTHSI   929.59          -1.45           -0.16   933.75   923.17
#  7      SETWB   911.12          -3.52           -0.38   919.17   905.25
#  8        mai   338.57           1.29            0.38   340.26   337.76
#
#     ปริมาณ  ('000 หุ้น)  มูลค่า  (ล้านบาท)
#  0             23061923          117095.61
#  1              3289303           77714.93
#  2              5131122           92684.61
#  3               817414            3582.92
# ...

# %%
df[0]
# Out:
#   Unnamed: 0   ล่าสุด  เปลี่ยน  แปลง  %เปลี่ยน  แปลง   สูงสุด   ต่ำสุด  \
# 0        SET  1482.38          -1.51           -0.10  1489.78  1475.01
# 1      SET50   947.28          -1.71           -0.18   953.60   940.86
# 2     SET100  2116.85          -3.39           -0.16  2130.57  2103.80
# 3       sSET   721.04          -1.61           -0.22   726.51   720.68
# 4    SETCLMV   970.42          -6.03           -0.62   979.68   965.81
# 5      SETHD  1050.40          -4.11           -0.39  1058.45  1042.83
# 6    SETTHSI   929.59          -1.45           -0.16   933.75   923.17
# 7      SETWB   911.12          -3.52           -0.38   919.17   905.25
# 8        mai   338.57           1.29            0.38   340.26   337.76
#
#    ปริมาณ  ('000 หุ้น)  มูลค่า  (ล้านบาท)
# 0             23061923          117095.61
# 1              3289303           77714.93
# 2              5131122           92684.61
# 3               817414            3582.92
# 4              2134929           56058.29
# ...

# %% [markdown]
# # แบบที่ 2

# %%
import requests
import pandas as pd

# %%
url = 'https://www.settrade.com/C13_MarketSummary.jsp?detail=SET50'

# %%
web_data = requests.get(url)
web_data.encoding = 'tis-620'

# %%
df = pd.read_html(web_data.text)

# %%
len(df)
# Out:
# 6

# %%
df
# Out:
# [  Unnamed: 0   ล่าสุด  เปลี่ยน  แปลง  %เปลี่ยน  แปลง   สูงสุด   ต่ำสุด  \
#  0        SET  1482.38          -1.51           -0.10  1489.78  1475.01
#  1      SET50   947.28          -1.71           -0.18   953.60   940.86
#  2     SET100  2116.85          -3.39           -0.16  2130.57  2103.80
#  3       sSET   721.04          -1.61           -0.22   726.51   720.68
#  4    SETCLMV   970.42          -6.03           -0.62   979.68   965.81
#  5      SETHD  1050.40          -4.11           -0.39  1058.45  1042.83
#  6    SETTHSI   929.59          -1.45           -0.16   933.75   923.17
#  7      SETWB   911.12          -3.52           -0.38   919.17   905.25
#  8        mai   338.57           1.29            0.38   340.26   337.76
#
#     ปริมาณ  ('000 หุ้น)  มูลค่า  (ล้านบาท)
#  0             23061923          117095.61
#  1              3289303           77714.93
#  2              5131122           92684.61
#  3               817414            3582.92
# ...

# %%
df[0]
# Out:
#   Unnamed: 0   ล่าสุด  เปลี่ยน  แปลง  %เปลี่ยน  แปลง   สูงสุด   ต่ำสุด  \
# 0        SET  1482.38          -1.51           -0.10  1489.78  1475.01
# 1      SET50   947.28          -1.71           -0.18   953.60   940.86
# 2     SET100  2116.85          -3.39           -0.16  2130.57  2103.80
# 3       sSET   721.04          -1.61           -0.22   726.51   720.68
# 4    SETCLMV   970.42          -6.03           -0.62   979.68   965.81
# 5      SETHD  1050.40          -4.11           -0.39  1058.45  1042.83
# 6    SETTHSI   929.59          -1.45           -0.16   933.75   923.17
# 7      SETWB   911.12          -3.52           -0.38   919.17   905.25
# 8        mai   338.57           1.29            0.38   340.26   337.76
#
#    ปริมาณ  ('000 หุ้น)  มูลค่า  (ล้านบาท)
# 0             23061923          117095.61
# 1              3289303           77714.93
# 2              5131122           92684.61
# 3               817414            3582.92
# 4              2134929           56058.29
# ...
